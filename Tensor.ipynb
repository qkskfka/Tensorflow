# %%
import tensorflow as tf

# %%
# 변수 a와 b를 미리 정의합니다.
a = tf.Variable(0.1)
b = tf.Variable(0.2)

# 키와 신발 사이의 관계를 표현하는 식입니다.
def 신발_예측(키):
    return 키 * a + b

# 손실 함수를 정의합니다.
def 손실함수(키):
    예측값 = 신발_예측(키)
    return tf.square(260 - 예측값)

# tf.function 데코레이터를 사용하여 손실 함수를 컴파일합니다.
@tf.function
def 최적화_단계(키):
    with tf.GradientTape() as tape:
        손실 = 손실함수(키)
    gradients = tape.gradient(손실, [a, b])
    opt.apply_gradients(zip(gradients, [a, b]))

# 옵티마이저를 정의합니다.
opt = tf.keras.optimizers.Adam(learning_rate=0.1)

# 옵티마이저를 사용하여 손실 함수를 최소화합니다.
for i in range(300):
    최적화_단계(170)  # 키 값을 직접 지정하여 사용
    print(a.numpy(), b.numpy())
# Out:
# 0.19999935 0.29999933
# 0.29974166 0.39974165
# 0.39902657 0.49902657
# 0.49762622 0.5976262
# 0.59528726 0.6952872
# 0.69172704 0.791727
# 0.7866315 0.8866315
# 0.8796569 0.9796569
# 0.97042876 1.0704287
# 1.0585449 1.1585448
# 1.1435785 1.2435784
# 1.225085 1.3250849
# 1.3026105 1.4026104
# 1.3757026 1.4757026
# 1.4439243 1.5439243
# 1.5068681 1.6068681
# 1.5641723 1.6641723
# 1.6155354 1.7155354
# 1.6607298 1.7607299
# 1.6996118 1.799612
# 1.7321278 1.832128
# 1.7583159 1.8583162
# 1.778304 1.8783042
# 1.7923038 1.8923041
# 1.8006022 1.9006025
# 1.8035508 1.9035511
# 1.8015554 1.9015557
# 1.7950639 1.8950641
# 1.7845563 1.8845565
# 1.770535 1.8705353
# 1.7535154 1.8535156
# 1.7340184 1.8340187
# 1.7125634 1.8125637
# 1.6896611 1.7896614
# 1.6658087 1.7658088
# 1.6414832 1.7414833
# 1.617137 1.7171371
# 1.5931927 1.6931928
# 1.5700383 1.6700385
# 1.5480232 1.6480234
# 1.5274543 1.6274544
# 1.5085928 1.608593
# 1.4916525 1.5916526
# 1.4767977 1.5767978
# 1.464143 1.5641432
# ...

# %%
import tensorflow as tf

train_x = [1, 2, 3, 4, 5, 6, 7]
train_y = [3, 5, 7, 9, 11, 13, 15]

a = tf.Variable(0.1)
b = tf.Variable(0.1)

def 손실함수():
    예측_y = train_x * a + b
    return tf.keras.losses.mse(train_y, 예측_y)

opt = tf.keras.optimizers.Adam(learning_rate=0.01)

for i in range(2900):
    with tf.GradientTape() as tape:
        loss = 손실함수()
    gradients = tape.gradient(loss, [a, b])
    opt.apply_gradients(zip(gradients, [a, b]))
    print(a.numpy(), b.numpy())
# Out:
# 0.10999993 0.10999993
# 0.11999828 0.11999825
# 0.12999411 0.12999398
# 0.13998623 0.13998595
# 0.14997369 0.14997314
# 0.15995546 0.15995453
# 0.16993043 0.169929
# 0.1798976 0.1798955
# 0.18985595 0.189853
# 0.19980447 0.19980045
# 0.20974214 0.20973682
# 0.21966799 0.21966112
# 0.22958103 0.22957234
# 0.2394803 0.23946951
# 0.2493649 0.24935168
# 0.2592339 0.2592179
# 0.2690864 0.26906726
# 0.2789215 0.27889886
# 0.2887384 0.28871185
# 0.29853624 0.29850537
# 0.30831426 0.30827862
# 0.31807166 0.3180308
# 0.32780772 0.32776117
# 0.3375217 0.33746895
# 0.3472129 0.34715346
# 0.3568807 0.356814
# 0.36652437 0.3664499
# 0.37614337 0.37606052
# 0.38573706 0.38564527
# 0.39530492 0.39520356
# 0.40484637 0.40473485
# 0.41436088 0.41423857
# 0.42384797 0.42371425
# 0.43330717 0.43316135
# 0.44273803 0.44257945
# 0.45214012 0.45196807
# 0.46151304 0.4613268
# 0.47085637 0.47065526
# 0.48016974 0.47995302
# 0.4894528 0.48921973
# 0.49870524 0.49845505
# 0.5079267 0.50765866
# ...
